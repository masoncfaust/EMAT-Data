# %% [markdown]
# # Multi level heading 1
#
# ## Multi level heading 2

# %% [markdown]
# 1. Ordered list 1
# 2. Ordered list 2
# 3. Ordered list 3

# %% [markdown]
# **Basic text format** *Basic text format*

# %% [markdown]
# ![5074.jpg](attachment:5074.jpg)
#
# Basic image format

# %%
a = 1
b = 2
c = 3

forLoopList = [a, b, c]

for eachVar in forLoopList:
    print(eachVar)
    
print("variable assesment, basic for loop and print statement")
# Out:
# 1
# 2
# 3
# variable assesment, basic for loop and print statement

# %%
def double(a):
    return a+a
print(double(5))

print("return statement")
# Out:
# 10
# return statement
